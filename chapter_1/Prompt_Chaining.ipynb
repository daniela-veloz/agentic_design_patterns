# %% [markdown]
# <a href="https://colab.research.google.com/github/daniela-veloz/agentic_design_patterns/blob/main/chapter_1/Prompt_Chaining.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

# !pip install langchain_openai

from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# For better security, load environment variables from a .env file
from dotenv import load_dotenv
load_dotenv()


# Initialize the Language Model (using ChatOpenAI is recommended)
llm = ChatOpenAI(temperature=0)

# --- Prompt 1: Extract Information ---
prompt_extract = ChatPromptTemplate.from_template(
    "Extract the technical specifications from the following text:\n\n{text_input}"
)

# --- Prompt 2: Transform to JSON ---
prompt_transform = ChatPromptTemplate.from_template(
    "Transform the following specifications into a JSON object with 'cpu', 'memory', and 'storage' as keys:\n\n{specifications}"
)

# --- Build the Chain using LCEL ---
# The StrOutputParser() converts the LLM's message output to a simple string.
extraction_chain = prompt_extract | llm | StrOutputParser()

# The full chain passes the output of the extraction chain into the 'specifications.'
# variable for the transformation prompt.
full_chain = (
    {"specifications": extraction_chain}
    | prompt_transform
    | llm
    | StrOutputParser()
)

# --- Run the Chain ---
input_text = "The new laptop model features a 3.5 GHz octa-core processor, 16GB of RAM, and a 1TB NVMe SSD."

# Execute the chain with the input text dictionary.
final_result = full_chain.invoke({"text_input": input_text})

print("\n--- Final JSON Output ---")
print(final_result)
# Out:
# Requirement already satisfied: langchain_openai in /opt/miniconda3/lib/python3.13/site-packages (1.1.4)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.1 in /opt/miniconda3/lib/python3.13/site-packages (from langchain_openai) (1.2.2)
# Requirement already satisfied: openai<3.0.0,>=1.109.1 in /opt/miniconda3/lib/python3.13/site-packages (from langchain_openai) (2.13.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in /opt/miniconda3/lib/python3.13/site-packages (from langchain_openai) (0.10.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /opt/miniconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.1->langchain_openai) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /opt/miniconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.1->langchain_openai) (0.3.45)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /opt/miniconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.1->langchain_openai) (24.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /opt/miniconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.1->langchain_openai) (2.12.4)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /opt/miniconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.1->langchain_openai) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /opt/miniconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.1->langchain_openai) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /opt/miniconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.1->langchain_openai) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /opt/miniconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.1->langchain_openai) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/miniconda3/lib/python3.13/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.1->langchain_openai) (2.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/miniconda3/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain_openai) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /opt/miniconda3/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain_openai) (3.11.1)
# Requirement already satisfied: requests<3,>=2 in /opt/miniconda3/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain_openai) (2.32.5)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /opt/miniconda3/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain_openai) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /opt/miniconda3/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain_openai) (0.23.0)
# Requirement already satisfied: anyio in /opt/miniconda3/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain_openai) (4.12.0)
# Requirement already satisfied: certifi in /opt/miniconda3/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain_openai) (2025.7.14)
# Requirement already satisfied: httpcore==1.* in /opt/miniconda3/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain_openai) (1.0.9)
# Requirement already satisfied: idna in /opt/miniconda3/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain_openai) (3.7)
# Requirement already satisfied: h11>=0.16 in /opt/miniconda3/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain_openai) (0.16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/miniconda3/lib/python3.13/site-packages (from openai<3.0.0,>=1.109.1->langchain_openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /opt/miniconda3/lib/python3.13/site-packages (from openai<3.0.0,>=1.109.1->langchain_openai) (0.10.0)
# Requirement already satisfied: sniffio in /opt/miniconda3/lib/python3.13/site-packages (from openai<3.0.0,>=1.109.1->langchain_openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /opt/miniconda3/lib/python3.13/site-packages (from openai<3.0.0,>=1.109.1->langchain_openai) (4.67.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/miniconda3/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.1->langchain_openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /opt/miniconda3/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.1->langchain_openai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/miniconda3/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.1->langchain_openai) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/miniconda3/lib/python3.13/site-packages (from requests<3,>=2->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain_openai) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/miniconda3/lib/python3.13/site-packages (from requests<3,>=2->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain_openai) (2.5.0)
# Requirement already satisfied: regex>=2022.1.18 in /opt/miniconda3/lib/python3.13/site-packages (from tiktoken<1.0.0,>=0.7.0->langchain_openai) (2025.7.34)
#
# --- Final JSON Output ---
# {
#     "cpu": {
#         "processor": "3.5 GHz octa-core"
#     },
#     "memory": {
#         "RAM": "16GB"
#     },
#     "storage": {
#         "Storage": "1TB NVMe SSD"
#     }
# }

# %%
# Out:
# --- Final JSON Output ---
# {
#     "cpu": {
#         "processor": "3.5 GHz octa-core"
#     },
#     "memory": {
#         "RAM": "16GB"
#     },
#     "storage": {
#         "Storage": "1TB NVMe SSD"
#     }
# }
