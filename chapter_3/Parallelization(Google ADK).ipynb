# %%
from google.adk.agents import LlmAgent, ParallelAgent, SequentialAgent
from google.adk.runners import InMemoryRunner
from google.adk.tools import google_search

GEMINI_MODEL = "gemini-2.0-flash"

# Researcher 1: Renewable Energy
researcher_agent_1 = LlmAgent(
     name="RenewableEnergyResearcher",
     model=GEMINI_MODEL,
     instruction="""You are an AI Research Assistant specializing in energy.
 Research the latest advancements in 'renewable energy sources'.
 Use the Google Search tool provided.
 Summarize your key findings concisely (1-2 sentences).
 Output *only* the summary.
 """,
     description="Researches renewable energy sources.",
     tools=[google_search],
     # Store result in state for the merger agent
     output_key="renewable_energy_result"
 )

# Researcher 2: Electric Vehicles
researcher_agent_2 = LlmAgent(
     name="EVResearcher",
     model=GEMINI_MODEL,
     instruction="""You are an AI Research Assistant specializing in transportation.
 Research the latest developments in 'electric vehicle technology'.
 Use the Google Search tool provided.
 Summarize your key findings concisely (1-2 sentences).
 Output *only* the summary.
 """,
     description="Researches electric vehicle technology.",
     tools=[google_search],
     # Store result in state for the merger agent
     output_key="ev_technology_result"
 )

# Researcher 3: Carbon Capture
researcher_agent_3 = LlmAgent(
     name="CarbonCaptureResearcher",
     model=GEMINI_MODEL,
     instruction="""You are an AI Research Assistant specializing in climate solutions.
 Research the current state of 'carbon capture methods'.
 Use the Google Search tool provided.
 Summarize your key findings concisely (1-2 sentences).
 Output *only* the summary.
 """,
     description="Researches carbon capture methods.",
     tools=[google_search],
     # Store result in state for the merger agent
     output_key="carbon_capture_result"
 )

# --- 2. Create the ParallelAgent (Runs researchers concurrently) ---
 # This agent orchestrates the concurrent execution of the researchers.
 # It finishes once all researchers have completed and stored their results in state.
parallel_research_agent = ParallelAgent(
     name="ParallelWebResearchAgent",
     sub_agents=[researcher_agent_1, researcher_agent_2, researcher_agent_3],
     description="Runs multiple research agents in parallel to gather information."
 )

# --- 3. Define the Merger Agent (Runs *after* the parallel agents) ---
 # This agent takes the results stored in the session state by the parallel agents
 # and synthesizes them into a single, structured response with attributions.
merger_agent = LlmAgent(
     name="SynthesisAgent",
     model=GEMINI_MODEL,  # Or potentially a more powerful model if needed for synthesis
     instruction="""You are an AI Assistant responsible for combining research findings into a structured report.

 Your primary task is to synthesize the following research summaries, clearly attributing findings to their source areas. Structure your response using headings for each topic. Ensure the report is coherent and integrates the key points smoothly.

 **Crucially: Your entire response MUST be grounded *exclusively* on the information provided in the 'Input Summaries' below. Do NOT add any external knowledge, facts, or details not present in these specific summaries.**

 **Input Summaries:**

 *   **Renewable Energy:**
     {renewable_energy_result}

 *   **Electric Vehicles:**
     {ev_technology_result}

 *   **Carbon Capture:**
     {carbon_capture_result}

 **Output Format:**

 ## Summary of Recent Sustainable Technology Advancements

 ### Renewable Energy Findings
 (Based on RenewableEnergyResearcher's findings)
 [Synthesize and elaborate *only* on the renewable energy input summary provided above.]

 ### Electric Vehicle Findings
 (Based on EVResearcher's findings)
 [Synthesize and elaborate *only* on the EV input summary provided above.]

 ### Carbon Capture Findings
 (Based on CarbonCaptureResearcher's findings)
 [Synthesize and elaborate *only* on the carbon capture input summary provided above.]

 ### Overall Conclusion
 [Provide a brief (1-2 sentence) concluding statement that connects *only* the findings presented above.]

 Output *only* the structured report following this format. Do not include introductory or concluding phrases outside this structure, and strictly adhere to using only the provided input summary content.
 """,
     description="Combines research findings from parallel agents into a structured, cited report, strictly grounded on provided inputs.",
     # No tools needed for merging
     # No output_key needed here, as its direct response is the final output of the sequence
 )


# --- 4. Create the SequentialAgent (Orchestrates the overall flow) ---
# This is the main agent that will be run. It first executes the ParallelAgent
# to populate the state, and then executes the MergerAgent to produce the final output.
sequential_pipeline_agent = SequentialAgent(
     name="ResearchAndSynthesisPipeline",
     # Run parallel research first, then merge
     sub_agents=[parallel_research_agent, merger_agent],
     description="Coordinates parallel research and synthesizes the results."
 )

# %%
root_agent = sequential_pipeline_agent

# --- 5. Run the agent and print results ---
print("=" * 80)
print("Starting Parallel Research and Synthesis Pipeline")
print("=" * 80)

# Create runner
runner = InMemoryRunner(root_agent)

# Run the agent with a simple trigger message
result = await runner.run_debug(
    "Please conduct research on sustainable technology advancements.",
    verbose=True
)

print("\n" + "=" * 80)
print("FINAL SYNTHESIZED REPORT")
print("=" * 80)
print(result)
print("=" * 80)
# Out:
# ================================================================================
# Starting Parallel Research and Synthesis Pipeline
# ================================================================================
#
#  ### Created new session: debug_session_id
#
# User > Please conduct research on sustainable technology advancements.
# EVResearcher > Advancements in sustainable technology include renewable energy solutions like floating wind turbines and perovskite solar cells, improvements in battery technology such as solid-state and lithium iron phosphate (LFP) batteries, and developments in carbon capture, utilization, and storage (CCUS) technologies. Also, green technology involves AI-powered energy management, predictive maintenance for eco-friendly devices, and AI-driven agriculture for efficient resource use and reduced carbon footprints.
#
# CarbonCaptureResearcher > Sustainable technology advancements encompass innovations that minimize environmental impact and promote eco-friendly practices, focusing on areas like renewable energy, energy efficiency, waste management, and the use of sustainable materials. Key trends include advancements in energy storage, green hydrogen, circular economy models, AI-driven optimization, sustainable materials, and carbon management technologies.
#
# RenewableEnergyResearcher > Recent advancements in sustainable technology include falling solar energy costs, innovations in wind energy (such as floating offshore wind farms and advanced blade designs), improved sustainable manufacturing processes, AI and smart grids for energy distribution, advanced solar panel technology like bifacial panels and perovskite solar cells, green hydrogen production, and advanced energy storage solutions like solid-state batteries. These technologies contribute to higher energy conversion efficiencies, reduced greenhouse gas emissions, and more efficient and reliable energy systems.
#
# SynthesisAgent > ## Summary of Recent Sustainable Technology Advancements
#
#  ### Renewable Energy Findings
#  (Based on RenewableEnergyResearcher's findings)
#  Recent advancements in sustainable technology include falling solar energy costs and innovations in wind energy, particularly floating offshore wind farms and advanced blade designs. There have also been improvements in sustainable manufacturing processes. Other key areas include the application of AI and smart grids for energy distribution, and advanced solar panel technology such as bifacial panels and perovskite solar cells. Green hydrogen production and advanced energy storage solutions like solid-state batteries are also contributing to higher energy conversion efficiencies, reduced greenhouse gas emissions, and more efficient and reliable energy systems.
#
#  ### Electric Vehicle Findings
#  (Based on EVResearcher's findings)
#  Advancements in sustainable technology related to electric vehicles include renewable energy solutions like floating wind turbines and perovskite solar cells, alongside improvements in battery technology such as solid-state and lithium iron phosphate (LFP) batteries. Also, green technology involves AI-powered energy management and predictive maintenance for eco-friendly devices. AI-driven agriculture is also a factor, contributing to efficient resource use and reduced carbon footprints. Developments in carbon capture, utilization, and storage (CCUS) technologies are also relevant.
#
#  ### Carbon Capture Findings
#  (Based on CarbonCaptureResearcher's findings)
#  Sustainable technology advancements encompass innovations that minimize environmental impact and promote eco-friendly practices, focusing on areas like renewable energy, energy efficiency, waste management, and the use of sustainable materials. Key trends include advancements in energy storage, green hydrogen, circular economy models, AI-driven optimization, sustainable materials, and carbon management technologies.
#
#  ### Overall Conclusion
#  Recent progress spans renewable energy, electric vehicles, and carbon capture, with common threads in AI-driven optimization and advancements in energy storage and materials, all contributing to minimizing environmental impact.
#
#
# ================================================================================
# FINAL SYNTHESIZED REPORT
# ================================================================================
# [Event(model_version='gemini-2.0-flash', content=Content(
#   parts=[
#     Part(
#       text="""Advancements in sustainable technology include renewable energy solutions like floating wind turbines and perovskite solar cells, improvements in battery technology such as solid-state and lithium iron phosphate (LFP) batteries, and developments in carbon capture, utilization, and storage (CCUS) technologies. Also, green technology involves AI-powered energy management, predictive maintenance for eco-friendly devices, and AI-driven agriculture for efficient resource use and reduced carbon footprints.
# """
#     ),
#   ],
#   role='model'
# ), grounding_metadata=GroundingMetadata(
#   grounding_chunks=[
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='triangleip.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQE6KyVF8cik46Kh7kIH24BcuhnQ1dC7hp0JSODHF0-P6OLKMOFchiEwdq8yg8hTySDfQLSvDyeKuS-TbajyWSkQN8Y4mNVqJlVMcmprjllbtftrrqcgD0ga-krz8UMbt3l2h2tuV9-0uQKTMn5-Ul_l_pR9jb99'
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='startus-insights.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQHrwzaXS9jquun18zi4-nH3fPil31JCgeiX-QOVhnScyCG_3zZKufiKA-D9jHJHHx9UcC7a-dlalaU-0hLQx6mEcWaKgkZLS-eHJfim6-rOct_trbc3Z79foMTsvZmdkLWVD_qDtuUYZ1duy6PgN23ZhH_35KKcOXMw1Ay3HGukEZbwtRErGw2VLtFX'
#       )
#     ),
#   ],
#   grounding_supports=[
#     GroundingSupport(
#       confidence_scores=[
#         0.027708914,
#         0.38525194,
#       ],
#       grounding_chunk_indices=[
#         0,
#         1,
#       ],
#       segment=Segment(
#         end_index=309,
#         text='Advancements in sustainable technology include renewable energy solutions like floating wind turbines and perovskite solar cells, improvements in battery technology such as solid-state and lithium iron phosphate (LFP) batteries, and developments in carbon capture, utilization, and storage (CCUS) technologies'
#       )
#     ),
#     GroundingSupport(
#       confidence_scores=[
#         0.838916,
#       ],
#       grounding_chunk_indices=[
#         0,
#       ],
#       segment=Segment(
#         end_index=504,
#         start_index=311,
#         text='Also, green technology involves AI-powered energy management, predictive maintenance for eco-friendly devices, and AI-driven agriculture for efficient resource use and reduced carbon footprints'
#       )
#     ),
#   ],
#   retrieval_metadata=RetrievalMetadata(),
#   search_entry_point=SearchEntryPoint(
#     rendered_content="""<style>
# .container {
#   align-items: center;
#   border-radius: 8px;
#   display: flex;
#   font-family: Google Sans, Roboto, sans-serif;
#   font-size: 14px;
#   line-height: 20px;
#   padding: 8px 12px;
# }
# .chip {
#   display: inline-block;
#   border: solid 1px;
#   border-radius: 16px;
#   min-width: 14px;
#   padding: 5px 16px;
#   text-align: center;
#   user-select: none;
#   margin: 0 8px;
#   -webkit-tap-highlight-color: transparent;
# }
# .carousel {
#   overflow: auto;
#   scrollbar-width: none;
#   white-space: nowrap;
#   margin-right: -12px;
# }
# .headline {
#   display: flex;
#   margin-right: 4px;
# }
# .gradient-container {
#   position: relative;
# }
# .gradient {
#   position: absolute;
#   transform: translate(3px, -9px);
#   height: 36px;
#   width: 9px;
# }
# @media (prefers-color-scheme: light) {
#   .container {
#     background-color: #fafafa;
#     box-shadow: 0 0 0 1px #0000000f;
#   }
#   .headline-label {
#     color: #1f1f1f;
#   }
#   .chip {
#     background-color: #ffffff;
#     border-color: #d2d2d2;
#     color: #5e5e5e;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #f2f2f2;
#   }
#   .chip:focus {
#     background-color: #f2f2f2;
#   }
#   .chip:active {
#     background-color: #d8d8d8;
#     border-color: #b6b6b6;
#   }
#   .logo-dark {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #fafafa 15%, #fafafa00 100%);
#   }
# }
# @media (prefers-color-scheme: dark) {
#   .container {
#     background-color: #1f1f1f;
#     box-shadow: 0 0 0 1px #ffffff26;
#   }
#   .headline-label {
#     color: #fff;
#   }
#   .chip {
#     background-color: #2c2c2c;
#     border-color: #3c4043;
#     color: #fff;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #353536;
#   }
#   .chip:focus {
#     background-color: #353536;
#   }
#   .chip:active {
#     background-color: #464849;
#     border-color: #53575b;
#   }
#   .logo-light {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #1f1f1f 15%, #1f1f1f00 100%);
#   }
# }
# </style>
# <div class="container">
#   <div class="headline">
#     <svg class="logo-light" width="18" height="18" viewBox="9 9 35 35" fill="none" xmlns="http://www.w3.org/2000/svg">
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M42.8622 27.0064C42.8622 25.7839 42.7525 24.6084 42.5487 23.4799H26.3109V30.1568H35.5897C35.1821 32.3041 33.9596 34.1222 32.1258 35.3448V39.6864H37.7213C40.9814 36.677 42.8622 32.2571 42.8622 27.0064V27.0064Z" fill="#4285F4"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 43.8555C30.9659 43.8555 34.8687 42.3195 37.7213 39.6863L32.1258 35.3447C30.5898 36.3792 28.6306 37.0061 26.3109 37.0061C21.8282 37.0061 18.0195 33.9811 16.6559 29.906H10.9194V34.3573C13.7563 39.9841 19.5712 43.8555 26.3109 43.8555V43.8555Z" fill="#34A853"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M16.6559 29.8904C16.3111 28.8559 16.1074 27.7588 16.1074 26.6146C16.1074 25.4704 16.3111 24.3733 16.6559 23.3388V18.8875H10.9194C9.74388 21.2072 9.06992 23.8247 9.06992 26.6146C9.06992 29.4045 9.74388 32.022 10.9194 34.3417L15.3864 30.8621L16.6559 29.8904V29.8904Z" fill="#FBBC05"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 16.2386C28.85 16.2386 31.107 17.1164 32.9095 18.8091L37.8466 13.8719C34.853 11.082 30.9659 9.3736 26.3109 9.3736C19.5712 9.3736 13.7563 13.245 10.9194 18.8875L16.6559 23.3388C18.0195 19.2636 21.8282 16.2386 26.3109 16.2386V16.2386Z" fill="#EA4335"/>
#     </svg>
#     <svg class="logo-dark" width="18" height="18" viewBox="0 0 48 48" xmlns="http://www.w3.org/2000/svg">
#       <circle cx="24" cy="23" fill="#FFF" r="22"/>
#       <path d="M33.76 34.26c2.75-2.56 4.49-6.37 4.49-11.26 0-.89-.08-1.84-.29-3H24.01v5.99h8.03c-.4 2.02-1.5 3.56-3.07 4.56v.75l3.91 2.97h.88z" fill="#4285F4"/>
#       <path d="M15.58 25.77A8.845 8.845 0 0 0 24 31.86c1.92 0 3.62-.46 4.97-1.31l4.79 3.71C31.14 36.7 27.65 38 24 38c-5.93 0-11.01-3.4-13.45-8.36l.17-1.01 4.06-2.85h.8z" fill="#34A853"/>
#       <path d="M15.59 20.21a8.864 8.864 0 0 0 0 5.58l-5.03 3.86c-.98-2-1.53-4.25-1.53-6.64 0-2.39.55-4.64 1.53-6.64l1-.22 3.81 2.98.22 1.08z" fill="#FBBC05"/>
#       <path d="M24 14.14c2.11 0 4.02.75 5.52 1.98l4.36-4.36C31.22 9.43 27.81 8 24 8c-5.93 0-11.01 3.4-13.45 8.36l5.03 3.85A8.86 8.86 0 0 1 24 14.14z" fill="#EA4335"/>
#     </svg>
#     <div class="gradient-container"><div class="gradient"></div></div>
#   </div>
#   <div class="carousel">
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQFsHd2dTX_lP6ke1xF7X2rIqj1cSJlCMplFwhIltkurxUbNVLXNWFgehB1ERy9cV7XgVC9roEYBYe1DY4536vkvNOXWHckLJhz61ppcj6nbd5JuaXGtkMFQ9-qHYswKJU99pnhF1yIwlDfB4f65kGmTZx7eMNTWgyNlVvW-kb1TMY7njg-24fq9PNj3zUPmb9qqxlVdeWZ4y_zHt3wIUgQJ9FRN_aOH7nnsrDnorn6R">latest advancements in sustainable technology</a>
#   </div>
# </div>
# """
#   ),
#   web_search_queries=[
#     'latest advancements in sustainable technology',
#   ]
# ), partial=None, turn_complete=None, finish_reason=<FinishReason.STOP: 'STOP'>, error_code=None, error_message=None, interrupted=None, custom_metadata=None, usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=88,
#   candidates_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=88
#     ),
#   ],
#   prompt_token_count=87,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=87
#     ),
#   ],
#   total_token_count=175
# ), live_session_resumption_update=None, input_transcription=None, output_transcription=None, avg_logprobs=None, logprobs_result=None, cache_metadata=None, citation_metadata=None, interaction_id=None, invocation_id='e-d0ac9e8b-3526-40b4-9229-1f31118f1c93', author='EVResearcher', actions=EventActions(skip_summarization=None, state_delta={'ev_technology_result': 'Advancements in sustainable technology include renewable energy solutions like floating wind turbines and perovskite solar cells, improvements in battery technology such as solid-state and lithium iron phosphate (LFP) batteries, and developments in carbon capture, utilization, and storage (CCUS) technologies. Also, green technology involves AI-powered energy management, predictive maintenance for eco-friendly devices, and AI-driven agriculture for efficient resource use and reduced carbon footprints.\n'}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction=None, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None), long_running_tool_ids=None, branch='ParallelWebResearchAgent.EVResearcher', id='e4e28b69-a3cc-47f3-b6d3-295bc448cd5f', timestamp=1767314469.180842), Event(model_version='gemini-2.0-flash', content=Content(
#   parts=[
#     Part(
#       text="""Sustainable technology advancements encompass innovations that minimize environmental impact and promote eco-friendly practices, focusing on areas like renewable energy, energy efficiency, waste management, and the use of sustainable materials. Key trends include advancements in energy storage, green hydrogen, circular economy models, AI-driven optimization, sustainable materials, and carbon management technologies.
# """
#     ),
#   ],
#   role='model'
# ), grounding_metadata=GroundingMetadata(
#   grounding_chunks=[
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='lythouse.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQHNRKCEXSTV6rqPL1z3OHvA-VxuTrocAur_XdRbdDRfsaCjgcxl37WMc1kOApn3Vc7ASOy7YEOlkxK1A6U5IReFvEBg6aar2XEWz0di5GOlHLB-D2yeMNNOsNfwILO73fXgoKILs82olweFk2wqg-YKAKGZyyMH6sUm8g=='
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='esade.edu',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQFIP5TaHvDS5V_XbxJj1HiqA2OuiaGJ-bt08OnVFil4P2uG4mG_cIm3aHW9LBmOvUfAnQvTlESn2WPcam-E9I0hKHX5OdIr7TT01qboBFIMw3K_MJYN4AiZ8D1UuADVDR6FcbiH3dWOYV77N2DEAzD6V5Y9QSP5VaX0'
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='mipaoverseas.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQFt6k07l5s6_3i_-6-S20yq_kSCjQT3YL-ZBp74nfzP9aAQ7C9qcWhtJLfcG7gU2VXDy9E3J4RmvNcxDvAW4uYkUCFuQ90ZIXrjWH4I4VTQM0UfFACLfijIEKPK2nnMlHP7ulCTY3HweK8yql5KTZMOSB2eEqVO4m7tCLg9j9Ks2g9QfY8Ac3c='
#       )
#     ),
#   ],
#   grounding_supports=[
#     GroundingSupport(
#       confidence_scores=[
#         0.77342033,
#         0.7681043,
#       ],
#       grounding_chunk_indices=[
#         0,
#         1,
#       ],
#       segment=Segment(
#         end_index=243,
#         text='Sustainable technology advancements encompass innovations that minimize environmental impact and promote eco-friendly practices, focusing on areas like renewable energy, energy efficiency, waste management, and the use of sustainable materials'
#       )
#     ),
#     GroundingSupport(
#       confidence_scores=[
#         0.91682434,
#       ],
#       grounding_chunk_indices=[
#         2,
#       ],
#       segment=Segment(
#         end_index=418,
#         start_index=245,
#         text='Key trends include advancements in energy storage, green hydrogen, circular economy models, AI-driven optimization, sustainable materials, and carbon management technologies'
#       )
#     ),
#   ],
#   retrieval_metadata=RetrievalMetadata(),
#   search_entry_point=SearchEntryPoint(
#     rendered_content="""<style>
# .container {
#   align-items: center;
#   border-radius: 8px;
#   display: flex;
#   font-family: Google Sans, Roboto, sans-serif;
#   font-size: 14px;
#   line-height: 20px;
#   padding: 8px 12px;
# }
# .chip {
#   display: inline-block;
#   border: solid 1px;
#   border-radius: 16px;
#   min-width: 14px;
#   padding: 5px 16px;
#   text-align: center;
#   user-select: none;
#   margin: 0 8px;
#   -webkit-tap-highlight-color: transparent;
# }
# .carousel {
#   overflow: auto;
#   scrollbar-width: none;
#   white-space: nowrap;
#   margin-right: -12px;
# }
# .headline {
#   display: flex;
#   margin-right: 4px;
# }
# .gradient-container {
#   position: relative;
# }
# .gradient {
#   position: absolute;
#   transform: translate(3px, -9px);
#   height: 36px;
#   width: 9px;
# }
# @media (prefers-color-scheme: light) {
#   .container {
#     background-color: #fafafa;
#     box-shadow: 0 0 0 1px #0000000f;
#   }
#   .headline-label {
#     color: #1f1f1f;
#   }
#   .chip {
#     background-color: #ffffff;
#     border-color: #d2d2d2;
#     color: #5e5e5e;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #f2f2f2;
#   }
#   .chip:focus {
#     background-color: #f2f2f2;
#   }
#   .chip:active {
#     background-color: #d8d8d8;
#     border-color: #b6b6b6;
#   }
#   .logo-dark {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #fafafa 15%, #fafafa00 100%);
#   }
# }
# @media (prefers-color-scheme: dark) {
#   .container {
#     background-color: #1f1f1f;
#     box-shadow: 0 0 0 1px #ffffff26;
#   }
#   .headline-label {
#     color: #fff;
#   }
#   .chip {
#     background-color: #2c2c2c;
#     border-color: #3c4043;
#     color: #fff;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #353536;
#   }
#   .chip:focus {
#     background-color: #353536;
#   }
#   .chip:active {
#     background-color: #464849;
#     border-color: #53575b;
#   }
#   .logo-light {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #1f1f1f 15%, #1f1f1f00 100%);
#   }
# }
# </style>
# <div class="container">
#   <div class="headline">
#     <svg class="logo-light" width="18" height="18" viewBox="9 9 35 35" fill="none" xmlns="http://www.w3.org/2000/svg">
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M42.8622 27.0064C42.8622 25.7839 42.7525 24.6084 42.5487 23.4799H26.3109V30.1568H35.5897C35.1821 32.3041 33.9596 34.1222 32.1258 35.3448V39.6864H37.7213C40.9814 36.677 42.8622 32.2571 42.8622 27.0064V27.0064Z" fill="#4285F4"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 43.8555C30.9659 43.8555 34.8687 42.3195 37.7213 39.6863L32.1258 35.3447C30.5898 36.3792 28.6306 37.0061 26.3109 37.0061C21.8282 37.0061 18.0195 33.9811 16.6559 29.906H10.9194V34.3573C13.7563 39.9841 19.5712 43.8555 26.3109 43.8555V43.8555Z" fill="#34A853"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M16.6559 29.8904C16.3111 28.8559 16.1074 27.7588 16.1074 26.6146C16.1074 25.4704 16.3111 24.3733 16.6559 23.3388V18.8875H10.9194C9.74388 21.2072 9.06992 23.8247 9.06992 26.6146C9.06992 29.4045 9.74388 32.022 10.9194 34.3417L15.3864 30.8621L16.6559 29.8904V29.8904Z" fill="#FBBC05"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 16.2386C28.85 16.2386 31.107 17.1164 32.9095 18.8091L37.8466 13.8719C34.853 11.082 30.9659 9.3736 26.3109 9.3736C19.5712 9.3736 13.7563 13.245 10.9194 18.8875L16.6559 23.3388C18.0195 19.2636 21.8282 16.2386 26.3109 16.2386V16.2386Z" fill="#EA4335"/>
#     </svg>
#     <svg class="logo-dark" width="18" height="18" viewBox="0 0 48 48" xmlns="http://www.w3.org/2000/svg">
#       <circle cx="24" cy="23" fill="#FFF" r="22"/>
#       <path d="M33.76 34.26c2.75-2.56 4.49-6.37 4.49-11.26 0-.89-.08-1.84-.29-3H24.01v5.99h8.03c-.4 2.02-1.5 3.56-3.07 4.56v.75l3.91 2.97h.88z" fill="#4285F4"/>
#       <path d="M15.58 25.77A8.845 8.845 0 0 0 24 31.86c1.92 0 3.62-.46 4.97-1.31l4.79 3.71C31.14 36.7 27.65 38 24 38c-5.93 0-11.01-3.4-13.45-8.36l.17-1.01 4.06-2.85h.8z" fill="#34A853"/>
#       <path d="M15.59 20.21a8.864 8.864 0 0 0 0 5.58l-5.03 3.86c-.98-2-1.53-4.25-1.53-6.64 0-2.39.55-4.64 1.53-6.64l1-.22 3.81 2.98.22 1.08z" fill="#FBBC05"/>
#       <path d="M24 14.14c2.11 0 4.02.75 5.52 1.98l4.36-4.36C31.22 9.43 27.81 8 24 8c-5.93 0-11.01 3.4-13.45 8.36l5.03 3.85A8.86 8.86 0 0 1 24 14.14z" fill="#EA4335"/>
#     </svg>
#     <div class="gradient-container"><div class="gradient"></div></div>
#   </div>
#   <div class="carousel">
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQGbUVxrvKeyrWvgDRPGLdPZrBGm4tUhj-efFv7D5_RNUB0KvVEqnEK6v7a5e_wwn1fv250IjiG3_zpULWJm62TY5uak51CgDUqNHmt9Hk3Uf6x8lu_kC-ZH22x4KQ1OYxkrnSEiE05BLajSoBrSosBksdMB7fvNN95G63akIrSW7hC9LlXVtZBIR7ikdUiTs7edRoQjSpN5yvqWuoSE3lXjMBuLaPU=">sustainable technology advancements</a>
#   </div>
# </div>
# """
#   ),
#   web_search_queries=[
#     'sustainable technology advancements',
#   ]
# ), partial=None, turn_complete=None, finish_reason=<FinishReason.STOP: 'STOP'>, error_code=None, error_message=None, interrupted=None, custom_metadata=None, usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=65,
#   candidates_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=65
#     ),
#   ],
#   prompt_token_count=89,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=89
#     ),
#   ],
#   total_token_count=154
# ), live_session_resumption_update=None, input_transcription=None, output_transcription=None, avg_logprobs=None, logprobs_result=None, cache_metadata=None, citation_metadata=None, interaction_id=None, invocation_id='e-d0ac9e8b-3526-40b4-9229-1f31118f1c93', author='CarbonCaptureResearcher', actions=EventActions(skip_summarization=None, state_delta={'carbon_capture_result': 'Sustainable technology advancements encompass innovations that minimize environmental impact and promote eco-friendly practices, focusing on areas like renewable energy, energy efficiency, waste management, and the use of sustainable materials. Key trends include advancements in energy storage, green hydrogen, circular economy models, AI-driven optimization, sustainable materials, and carbon management technologies.\n'}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction=None, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None), long_running_tool_ids=None, branch='ParallelWebResearchAgent.CarbonCaptureResearcher', id='cb8c5cfb-7ad3-48ae-840f-42fc70bb48e3', timestamp=1767314469.193926), Event(model_version='gemini-2.0-flash', content=Content(
#   parts=[
#     Part(
#       text="""Recent advancements in sustainable technology include falling solar energy costs, innovations in wind energy (such as floating offshore wind farms and advanced blade designs), improved sustainable manufacturing processes, AI and smart grids for energy distribution, advanced solar panel technology like bifacial panels and perovskite solar cells, green hydrogen production, and advanced energy storage solutions like solid-state batteries. These technologies contribute to higher energy conversion efficiencies, reduced greenhouse gas emissions, and more efficient and reliable energy systems.
# """
#     ),
#   ],
#   role='model'
# ), grounding_metadata=GroundingMetadata(
#   grounding_chunks=[
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='instituteofsustainabilitystudies.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQFw5jqquZzKZdN8QxInBnmGhDMhBYxSfH-4G1NDyayVa7SRD71qmEnAQL2XXt9qmhkNnxAQAuE20RU5YJWBOUPpVWmh4t_LXRYsI0zlhvecV84JH24uzlgmvZA38y1YvUm6BQeeTGT9zTYlTg9Pn3cY3BvXXRxCgvM4Jzx0PBgu_hrRT80krkcMq0b-lmLKoxrROC1Tv8rEdGTKS-OCH1w1yY2KX_51OvCREXkglIcuSlQrz2mT'
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='energyevolutionconference.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQG8n_G8nnnMvcYQSkUzdhqPfXCJixUWcu3BO6FFh5Tc7CV83pQZbWtejsLxMO3FoE-sL2hzOmcIhzy6VAmtbRlVoR-Wn4bcOXfNmmatDGyI44v4e9-Ec9_oPEFVssA1Q5awXYZd8M_VbBBJsPP67OOxBYaCr2t1Vt_vIsNgVfqfR-lgofk1Yw=='
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='greencitytimes.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQFhnBZVQDD99x6P6wzaCfe6sNSIMEEIjm08ha4D86HHhgLFWpQ19Xn8VBsua9yQRQKRVu3mX6cQGKR73pwaAYswrlUEJlgRPKBoOLz5CrWBHihxDt_NX_goCrwjMHQv-wygNLsL0C15gQLqWZejanfAS1uwqspPdU6eBoFU4QIQdbsCUqxsk6dNTnC3rv8='
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='tomorrowsaffairs.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQFVhi3vrhjQE6-VInXbFpKaXoWLjofkj1PZriFkZ64QLg3qqLW8pvUI5ruNvHPU8QsIFsSjGvVPOaXjAx6dhS_qFtpVzOMfy_9ZoFtXuB6emEmhqCYheUzEnRXWibfxOn952wxrKrZ-Xfo6rCQGESVxmc-5QlytPIt4gPQmr7YHIEAZcryGCPG8vJvxjXB9sxvI4MQMTkQyGVMuhbBp'
#       )
#     ),
#   ],
#   grounding_supports=[
#     GroundingSupport(
#       confidence_scores=[
#         0.12185273,
#         0.2868492,
#         0.10325675,
#         0.22925065,
#       ],
#       grounding_chunk_indices=[
#         0,
#         1,
#         2,
#         3,
#       ],
#       segment=Segment(
#         end_index=438,
#         text='Recent advancements in sustainable technology include falling solar energy costs, innovations in wind energy (such as floating offshore wind farms and advanced blade designs), improved sustainable manufacturing processes, AI and smart grids for energy distribution, advanced solar panel technology like bifacial panels and perovskite solar cells, green hydrogen production, and advanced energy storage solutions like solid-state batteries'
#       )
#     ),
#     GroundingSupport(
#       confidence_scores=[
#         0.1926047,
#         0.1101893,
#       ],
#       grounding_chunk_indices=[
#         0,
#         2,
#       ],
#       segment=Segment(
#         end_index=592,
#         start_index=440,
#         text='These technologies contribute to higher energy conversion efficiencies, reduced greenhouse gas emissions, and more efficient and reliable energy systems'
#       )
#     ),
#   ],
#   retrieval_metadata=RetrievalMetadata(),
#   search_entry_point=SearchEntryPoint(
#     rendered_content="""<style>
# .container {
#   align-items: center;
#   border-radius: 8px;
#   display: flex;
#   font-family: Google Sans, Roboto, sans-serif;
#   font-size: 14px;
#   line-height: 20px;
#   padding: 8px 12px;
# }
# .chip {
#   display: inline-block;
#   border: solid 1px;
#   border-radius: 16px;
#   min-width: 14px;
#   padding: 5px 16px;
#   text-align: center;
#   user-select: none;
#   margin: 0 8px;
#   -webkit-tap-highlight-color: transparent;
# }
# .carousel {
#   overflow: auto;
#   scrollbar-width: none;
#   white-space: nowrap;
#   margin-right: -12px;
# }
# .headline {
#   display: flex;
#   margin-right: 4px;
# }
# .gradient-container {
#   position: relative;
# }
# .gradient {
#   position: absolute;
#   transform: translate(3px, -9px);
#   height: 36px;
#   width: 9px;
# }
# @media (prefers-color-scheme: light) {
#   .container {
#     background-color: #fafafa;
#     box-shadow: 0 0 0 1px #0000000f;
#   }
#   .headline-label {
#     color: #1f1f1f;
#   }
#   .chip {
#     background-color: #ffffff;
#     border-color: #d2d2d2;
#     color: #5e5e5e;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #f2f2f2;
#   }
#   .chip:focus {
#     background-color: #f2f2f2;
#   }
#   .chip:active {
#     background-color: #d8d8d8;
#     border-color: #b6b6b6;
#   }
#   .logo-dark {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #fafafa 15%, #fafafa00 100%);
#   }
# }
# @media (prefers-color-scheme: dark) {
#   .container {
#     background-color: #1f1f1f;
#     box-shadow: 0 0 0 1px #ffffff26;
#   }
#   .headline-label {
#     color: #fff;
#   }
#   .chip {
#     background-color: #2c2c2c;
#     border-color: #3c4043;
#     color: #fff;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #353536;
#   }
#   .chip:focus {
#     background-color: #353536;
#   }
#   .chip:active {
#     background-color: #464849;
#     border-color: #53575b;
#   }
#   .logo-light {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #1f1f1f 15%, #1f1f1f00 100%);
#   }
# }
# </style>
# <div class="container">
#   <div class="headline">
#     <svg class="logo-light" width="18" height="18" viewBox="9 9 35 35" fill="none" xmlns="http://www.w3.org/2000/svg">
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M42.8622 27.0064C42.8622 25.7839 42.7525 24.6084 42.5487 23.4799H26.3109V30.1568H35.5897C35.1821 32.3041 33.9596 34.1222 32.1258 35.3448V39.6864H37.7213C40.9814 36.677 42.8622 32.2571 42.8622 27.0064V27.0064Z" fill="#4285F4"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 43.8555C30.9659 43.8555 34.8687 42.3195 37.7213 39.6863L32.1258 35.3447C30.5898 36.3792 28.6306 37.0061 26.3109 37.0061C21.8282 37.0061 18.0195 33.9811 16.6559 29.906H10.9194V34.3573C13.7563 39.9841 19.5712 43.8555 26.3109 43.8555V43.8555Z" fill="#34A853"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M16.6559 29.8904C16.3111 28.8559 16.1074 27.7588 16.1074 26.6146C16.1074 25.4704 16.3111 24.3733 16.6559 23.3388V18.8875H10.9194C9.74388 21.2072 9.06992 23.8247 9.06992 26.6146C9.06992 29.4045 9.74388 32.022 10.9194 34.3417L15.3864 30.8621L16.6559 29.8904V29.8904Z" fill="#FBBC05"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 16.2386C28.85 16.2386 31.107 17.1164 32.9095 18.8091L37.8466 13.8719C34.853 11.082 30.9659 9.3736 26.3109 9.3736C19.5712 9.3736 13.7563 13.245 10.9194 18.8875L16.6559 23.3388C18.0195 19.2636 21.8282 16.2386 26.3109 16.2386V16.2386Z" fill="#EA4335"/>
#     </svg>
#     <svg class="logo-dark" width="18" height="18" viewBox="0 0 48 48" xmlns="http://www.w3.org/2000/svg">
#       <circle cx="24" cy="23" fill="#FFF" r="22"/>
#       <path d="M33.76 34.26c2.75-2.56 4.49-6.37 4.49-11.26 0-.89-.08-1.84-.29-3H24.01v5.99h8.03c-.4 2.02-1.5 3.56-3.07 4.56v.75l3.91 2.97h.88z" fill="#4285F4"/>
#       <path d="M15.58 25.77A8.845 8.845 0 0 0 24 31.86c1.92 0 3.62-.46 4.97-1.31l4.79 3.71C31.14 36.7 27.65 38 24 38c-5.93 0-11.01-3.4-13.45-8.36l.17-1.01 4.06-2.85h.8z" fill="#34A853"/>
#       <path d="M15.59 20.21a8.864 8.864 0 0 0 0 5.58l-5.03 3.86c-.98-2-1.53-4.25-1.53-6.64 0-2.39.55-4.64 1.53-6.64l1-.22 3.81 2.98.22 1.08z" fill="#FBBC05"/>
#       <path d="M24 14.14c2.11 0 4.02.75 5.52 1.98l4.36-4.36C31.22 9.43 27.81 8 24 8c-5.93 0-11.01 3.4-13.45 8.36l5.03 3.85A8.86 8.86 0 0 1 24 14.14z" fill="#EA4335"/>
#     </svg>
#     <div class="gradient-container"><div class="gradient"></div></div>
#   </div>
#   <div class="carousel">
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQH3-s_SmEyBSiwl4T98TNHlSJNP7Ay5p5ruH7FJYb6anwQn6xMnQcATL51BoSB88LDgaQL2tnnx9_QWIXpMpLKm-ibIJgyw5kGhlOF48EWyq3a6xoU7ktsszX2Hre6xEjkR8_cCIKfyejaTY6vxVRgLJKuLiFeZYO11ERB6--IXfRGkDofEyvBIPuG-F2H1junBsSR7fi_C2EpyRhzk2ozsPKRFrjbdQKzviKWZ">latest sustainable technology advancements</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQGq8XAlLUvd8P3IJSTnvdSFxkujqR4ZRAox20wVNC4abaCRhyVubFpz7NQoXQYiozr91xpDUGNykAeyJyrE1ligYi_bLVodFG1mL3l8iw-4Dt_AzgeDs7oFoPeuZqNTYACMtyCES0bJ3Umq7MLf2vJwu3LMAIoNMYklccebG2x-AGCXcnz3Zl_18Uv9PhvSxVBZB0H5PJdgxAv6pAxn4g21N8_nee12DgGxqJrovOYJXrQs4ekX">recent developments in renewable energy technology</a>
#   </div>
# </div>
# """
#   ),
#   web_search_queries=[
#     'latest sustainable technology advancements',
#     'recent developments in renewable energy technology',
#   ]
# ), partial=None, turn_complete=None, finish_reason=<FinishReason.STOP: 'STOP'>, error_code=None, error_message=None, interrupted=None, custom_metadata=None, usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=92,
#   candidates_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=92
#     ),
#   ],
#   prompt_token_count=89,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=89
#     ),
#   ],
#   total_token_count=181
# ), live_session_resumption_update=None, input_transcription=None, output_transcription=None, avg_logprobs=None, logprobs_result=None, cache_metadata=None, citation_metadata=None, interaction_id=None, invocation_id='e-d0ac9e8b-3526-40b4-9229-1f31118f1c93', author='RenewableEnergyResearcher', actions=EventActions(skip_summarization=None, state_delta={'renewable_energy_result': 'Recent advancements in sustainable technology include falling solar energy costs, innovations in wind energy (such as floating offshore wind farms and advanced blade designs), improved sustainable manufacturing processes, AI and smart grids for energy distribution, advanced solar panel technology like bifacial panels and perovskite solar cells, green hydrogen production, and advanced energy storage solutions like solid-state batteries. These technologies contribute to higher energy conversion efficiencies, reduced greenhouse gas emissions, and more efficient and reliable energy systems.\n'}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction=None, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None), long_running_tool_ids=None, branch='ParallelWebResearchAgent.RenewableEnergyResearcher', id='1ce3a9f8-d414-4fdf-b1ed-1ba4b68a5903', timestamp=1767314469.164602), Event(model_version='gemini-2.0-flash', content=Content(
#   parts=[
#     Part(
#       text="""## Summary of Recent Sustainable Technology Advancements
#
#  ### Renewable Energy Findings
#  (Based on RenewableEnergyResearcher's findings)
#  Recent advancements in sustainable technology include falling solar energy costs and innovations in wind energy, particularly floating offshore wind farms and advanced blade designs. There have also been improvements in sustainable manufacturing processes. Other key areas include the application of AI and smart grids for energy distribution, and advanced solar panel technology such as bifacial panels and perovskite solar cells. Green hydrogen production and advanced energy storage solutions like solid-state batteries are also contributing to higher energy conversion efficiencies, reduced greenhouse gas emissions, and more efficient and reliable energy systems.
#
#  ### Electric Vehicle Findings
#  (Based on EVResearcher's findings)
#  Advancements in sustainable technology related to electric vehicles include renewable energy solutions like floating wind turbines and perovskite solar cells, alongside improvements in battery technology such as solid-state and lithium iron phosphate (LFP) batteries. Also, green technology involves AI-powered energy management and predictive maintenance for eco-friendly devices. AI-driven agriculture is also a factor, contributing to efficient resource use and reduced carbon footprints. Developments in carbon capture, utilization, and storage (CCUS) technologies are also relevant.
#
#  ### Carbon Capture Findings
#  (Based on CarbonCaptureResearcher's findings)
#  Sustainable technology advancements encompass innovations that minimize environmental impact and promote eco-friendly practices, focusing on areas like renewable energy, energy efficiency, waste management, and the use of sustainable materials. Key trends include advancements in energy storage, green hydrogen, circular economy models, AI-driven optimization, sustainable materials, and carbon management technologies.
#
#  ### Overall Conclusion
#  Recent progress spans renewable energy, electric vehicles, and carbon capture, with common threads in AI-driven optimization and advancements in energy storage and materials, all contributing to minimizing environmental impact.
# """
#     ),
#   ],
#   role='model'
# ), grounding_metadata=None, partial=None, turn_complete=None, finish_reason=<FinishReason.STOP: 'STOP'>, error_code=None, error_message=None, interrupted=None, custom_metadata=None, usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=365,
#   candidates_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=365
#     ),
#   ],
#   prompt_token_count=879,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=879
#     ),
#   ],
#   total_token_count=1244
# ), live_session_resumption_update=None, input_transcription=None, output_transcription=None, avg_logprobs=-0.19837274420751283, logprobs_result=None, cache_metadata=None, citation_metadata=None, interaction_id=None, invocation_id='e-d0ac9e8b-3526-40b4-9229-1f31118f1c93', author='SynthesisAgent', actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction=None, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None), long_running_tool_ids=None, branch=None, id='31047558-5994-48ff-b093-638a7dc0302a', timestamp=1767314471.867635)]
# ================================================================================
