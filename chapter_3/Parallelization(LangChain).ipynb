# %%
# Dependencies managed via uv - see pyproject.toml
# This notebook requires: langchain-openai, python-dotenv

# %%
import os
import asyncio
from typing import Optional

from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import Runnable, RunnableParallel, RunnablePassthrough

# --- Configuration ---
# Ensure your API key environment variable is set (e.g., OPENAI_API_KEY)
from dotenv import load_dotenv
load_dotenv()

try:
    llm: Optional[ChatOpenAI] = ChatOpenAI(model="gpt-4o-mini", temperature=0.7)
    if llm:
        print(f"Language model initialized: {llm.model_name}")
except Exception as e:
    print(f"Error initializing language model: {e}")
    llm = None


# --- Define Independent Chains ---
# These three chains represent distinct tasks that can be executed in parallel.

summarize_chain: Runnable = (
    ChatPromptTemplate.from_messages([
        ("system", "Summarize the following topic concisely:"),
        ("user", "{topic}")
    ])
    | llm
    | StrOutputParser()
)

questions_chain: Runnable = (
    ChatPromptTemplate.from_messages([
        ("system", "Generate three interesting questions about the following topic:"),
        ("user", "{topic}")
    ])
    | llm
    | StrOutputParser()
)

terms_chain: Runnable = (
    ChatPromptTemplate.from_messages([
        ("system", "Identify 5-10 key terms from the following topic, separated by commas:"),
        ("user", "{topic}")
    ])
    | llm
    | StrOutputParser()
)


# --- Build the Parallel + Synthesis Chain ---

# 1. Define the block of tasks to run in parallel. The results of these,
#    along with the original topic, will be fed into the next step.
map_chain = RunnableParallel(
    {
        "summary": summarize_chain,
        "questions": questions_chain,
        "key_terms": terms_chain,
        "topic": RunnablePassthrough(),  # Pass the original topic through
    }
)

# 2. Define the final synthesis prompt which will combine the parallel results.
synthesis_prompt = ChatPromptTemplate.from_messages([
    ("system", """Based on the following information:
     Summary: {summary}
     Related Questions: {questions}
     Key Terms: {key_terms}
     Synthesize a comprehensive answer."""),
    ("user", "Original topic: {topic}")
])

# 3. Construct the full chain by piping the parallel results directly
#    into the synthesis prompt, followed by the LLM and output parser.
full_parallel_chain = map_chain | synthesis_prompt | llm | StrOutputParser()


# --- Run the Chain ---
async def run_parallel_example(topic: str) -> None:
    """
    Asynchronously invokes the parallel processing chain with a specific topic
    and prints the synthesized result.

    Args:
        topic: The input topic to be processed by the LangChain chains.
    """
    if not llm:
        print("LLM not initialized. Cannot run example.")
        return

    print(f"\n--- Running Parallel LangChain Example for Topic: '{topic}' ---")
    try:
        # The input to `ainvoke` is the single 'topic' string, which is
        # then passed to each runnable in the `map_chain`.
        response = await full_parallel_chain.ainvoke(topic)
        print("\n--- Final Response ---")
        print(response)
    except Exception as e:
        print(f"\nAn error occurred during chain execution: {e}")

# --- Execute in Jupyter ---
# In Jupyter notebooks, use await directly instead of asyncio.run()
# since Jupyter already runs an event loop
test_topic = "The history of space exploration"
await run_parallel_example(test_topic)
# Out:
# Language model initialized: gpt-4o-mini
#
# --- Running Parallel LangChain Example for Topic: 'The history of space exploration' ---
#
# --- Final Response ---
# The history of space exploration is a fascinating journey that began in the mid-20th century, primarily characterized by the fierce competition between the United States and the Soviet Union during the Cold War, known as the Space Race. This period marked significant milestones that not only showcased human ingenuity but also paved the way for future endeavors in space.
#
# The Space Race was ignited by the Soviet Union's launch of Sputnik 1 in 1957, the first artificial satellite to orbit the Earth. This groundbreaking event not only demonstrated the USSR's technological prowess but also raised concerns in the U.S. about national security and scientific leadership. In response, the United States accelerated its own space programs, leading to key milestones such as Yuri Gagarin becoming the first human in space in 1961, and the Apollo 11 mission in 1969, which successfully landed astronauts Neil Armstrong and Buzz Aldrin on the moon. These events were pivotal in shaping public interest and government investment in space exploration.
#
# As the decades progressed, the focus of space exploration shifted from merely achieving milestones to developing sustainable scientific endeavors. The 1970s and 1980s saw the advent of space probes like Voyager, which provided invaluable data about the outer planets, and the establishment of the Space Shuttle program, which allowed for reusable spacecraft and paved the way for the construction of space stations. The International Space Station (ISS), a collaborative project launched in the 1990s, marked a significant shift towards international cooperation in space exploration, bringing together multiple countries and agencies to work on scientific research in microgravity.
#
# In recent years, advancements in technology have continued to redefine space exploration. The development of Mars rovers, such as Spirit, Opportunity, and Curiosity, has enabled detailed exploration of the Martian surface, while space telescopes like Hubble have expanded our understanding of the universe. Moreover, the emergence of commercial spaceflight has introduced new players into the arena, leading to a paradigm shift in how space missions are conceived and executed. Companies like SpaceX, Blue Origin, and others are not only reducing costs but also fostering innovation, making space more accessible.
#
# However, the involvement of private companies in space exploration raises several ethical considerations. Issues such as the commercialization of space, the potential for space debris, the militarization of space, and the equitable use of resources are increasingly pertinent. The privatization of space activities may lead to a future where profit motives overshadow scientific exploration and international cooperation.
#
# In summary, the history of space exploration is a testament to human curiosity and resilience, marked by groundbreaking achievements and collaborative efforts. As we look toward the future, missions to Mars and beyond will continue to challenge our technological capabilities and ethical frameworks, shaping the next chapter in humanity's quest to explore the cosmos. The interplay between public institutions and private enterprises will be crucial in determining how we navigate the new frontier of space exploration.
