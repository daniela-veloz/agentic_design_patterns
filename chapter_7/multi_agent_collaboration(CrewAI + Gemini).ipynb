# %%
import os
from dotenv import load_dotenv
from crewai import Agent, Task, Crew, Process
from langchain_google_genai import ChatGoogleGenerativeAI

def setup_environment():
    """Loads environment variables and checks for the required API key."""
    load_dotenv()
    if not os.getenv("GOOGLE_API_KEY"):
        raise ValueError("GOOGLE_API_KEY not found. Please set it in your .env file.")

def main():
    """
    Initializes and runs the AI crew for content creation using the latest Gemini model.
    """
    setup_environment()

    # Define the language model to use.
    # Updated to a model from the Gemini 2.0 series for better performance and features.
    # For cutting-edge (preview) capabilities, you could use "gemini-2.5-flash".
    llm = ChatGoogleGenerativeAI(model="gemini-2.0-flash")

    # Define Agents with specific roles and goals
    researcher = Agent(
        role='Senior Research Analyst',
        goal='Find and summarize the latest trends in AI.',
        backstory="You are an experienced research analyst with a knack for identifying key trends and synthesizing information.",
        verbose=True,
        allow_delegation=False,
    )

    writer = Agent(
        role='Technical Content Writer',
        goal='Write a clear and engaging blog post based on research findings.',
        backstory="You are a skilled writer who can translate complex technical topics into accessible content.",
        verbose=True,
        allow_delegation=False,
    )

    # Define Tasks for the agents
    research_task = Task(
        description="Research the top 3 emerging trends in Artificial Intelligence in 2024-2025. Focus on practical applications and potential impact.",
        expected_output="A detailed summary of the top 3 AI trends, including key points and sources.",
        agent=researcher,
    )

    writing_task = Task(
        description="Write a 500-word blog post based on the research findings. The post should be engaging and easy for a general audience to understand.",
        expected_output="A complete 500-word blog post about the latest AI trends.",
        agent=writer,
        context=[research_task],
    )

    # Create the Crew
    blog_creation_crew = Crew(
        agents=[researcher, writer],
        tasks=[research_task, writing_task],
        process=Process.sequential,
        llm=llm,
        verbose=True  # Changed from 2 to True - verbose expects a boolean value
    )

    # Execute the Crew
    print("## Running the blog creation crew with Gemini 2.0 Flash... ##")
    try:
        result = blog_creation_crew.kickoff()
        print("\n------------------\n")
        print("## Crew Final Output ##")
        print(result)
    except Exception as e:
        print(f"\nAn unexpected error occurred: {e}")

if __name__ == "__main__":
    main()
# Out:
# ## Running the blog creation crew with Gemini 2.0 Flash... ##
# ╭──────────────────────────────────────────── Crew Execution Started ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: f2d128c8-7fa3-404e-9714-0a33cb35295a                                                                       │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Senior Research Analyst                                                                                 │
# │                                                                                                                 │
# │  Task: Research the top 3 emerging trends in Artificial Intelligence in 2024-2025. Focus on practical           │
# │  applications and potential impact.                                                                             │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Senior Research Analyst                                                                                 │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Top 3 Emerging Trends in Artificial Intelligence in 2024-2025: Practical Applications and Potential Impact     │
# │                                                                                                                 │
# │  1. **Generative AI and Foundation Models Expansion**                                                           │
# │                                                                                                                 │
# │     - **Key Points:**                                                                                           │
# │       - Generative AI, powered by large foundation models such as GPT-4, PaLM 2, and other multimodal models,   │
# │  is evolving rapidly. These models are becoming more advanced at producing text, images, audio, code, and       │
# │  video content.                                                                                                 │
# │       - A trend toward multimodal foundation models allows seamless integration and generation of multiple      │
# │  data formats (text, images, video, audio) within a single AI system, enhancing creativity, automation, and     │
# │  interaction.                                                                                                   │
# │       - Practical applications span content creation (automated marketing materials, deepfake detection and     │
# │  generation, personalized media), coding assistance (auto-completion, bug fixing), and interactive chatbots     │
# │  with more human-like understanding.                                                                            │
# │       - AI-as-a-service platforms are becoming mainstream, democratizing access to powerful AI capabilities     │
# │  for businesses of all sizes.                                                                                   │
# │       - Ethical AI and robustness are emphasized due to risks of misinformation, bias, and misuse.              │
# │                                                                                                                 │
# │     - **Potential Impact:**                                                                                     │
# │       - Transforms industries such as media, software development, education, and customer service by           │
# │  enhancing productivity and enabling novel creative workflows.                                                  │
# │       - Enables hyper-personalization of products and services on an unprecedented scale.                       │
# │       - Raises important regulatory and governance challenges, pushing forward new standards for safe and       │
# │  ethical AI deployment.                                                                                         │
# │                                                                                                                 │
# │     - **Sources:**                                                                                              │
# │       - OpenAI's GPT-4 Technical Report (2024)                                                                  │
# │       - Google AI Blog on PaLM 2 and Gemini models (2024)                                                       │
# │       - Stanford Institute for Human-Centered AI Annual Report (2024)                                           │
# │                                                                                                                 │
# │  2. **AI-Driven Automation in Knowledge Work and Decision-Making**                                              │
# │                                                                                                                 │
# │     - **Key Points:**                                                                                           │
# │       - AI tools are increasingly integrated into enterprise workflows, automating complex knowledge work such  │
# │  as legal document review, financial analysis, and medical diagnostics.                                         │
# │       - Augmented decision-making frameworks combine human expertise with AI insights, improving accuracy,      │
# │  speed, and scalability of decisions in areas like healthcare, finance, and supply chain logistics.             │
# │       - Explainable AI (XAI) technologies become more critical to ensure transparency in automated decisions,   │
# │  particularly in regulated industries.                                                                          │
# │       - AI-powered robotic process automation (RPA) extends into unstructured data, allowing organizations to   │
# │  automate tasks previously too complex for RPA alone.                                                           │
# │       - Real-time data synthesis and predictive analytics enable proactive business strategies and risk         │
# │  management.                                                                                                    │
# │                                                                                                                 │
# │     - **Potential Impact:**                                                                                     │
# │       - Drives significant efficiency and cost savings in knowledge-intensive sectors.                          │
# │       - Enhances the quality and consistency of high-stakes decisions, reducing human error.                    │
# │       - Helps organizations adapt quickly to market changes and complex regulatory environments.                │
# │       - Augments human capabilities rather than fully replacing roles, creating new hybrid job functions.       │
# │                                                                                                                 │
# │     - **Sources:**                                                                                              │
# │       - McKinsey Global AI Survey 2024                                                                          │
# │       - Gartner Hype Cycle for Artificial Intelligence, 2024                                                    │
# │       - Deloitte Insights – AI in Knowledge Work (2024)                                                         │
# │                                                                                                                 │
# │  3. **AI for Scientific Discovery and Environmental Sustainability**                                            │
# │                                                                                                                 │
# │     - **Key Points:**                                                                                           │
# │       - AI models accelerate discovery in domains such as drug development, materials science, and genomics by  │
# │  predicting molecular structures, optimizing experiments, and analyzing vast datasets.                          │
# │       - Climate modeling and environmental monitoring are enhanced by AI-driven simulations to better           │
# │  understand climate change effects and optimize renewable energy systems.                                       │
# │       - Autonomous robotics guided by AI are increasingly used in environmental cleanup, agriculture            │
# │  (precision farming), and biodiversity conservation.                                                            │
# │       - Collaborative AI-human research platforms enable faster hypothesis testing and innovation cycles.       │
# │       - Ethical considerations focus on balancing accelerated innovation with environmental and societal        │
# │  risks.                                                                                                         │
# │                                                                                                                 │
# │     - **Potential Impact:**                                                                                     │
# │       - Potentially revolutionizes healthcare by drastically shortening the time to develop new treatments.     │
# │       - Provides critical tools to combat climate change and manage natural resources sustainably.              │
# │       - Promotes interdisciplinary collaboration and democratizes access to research capabilities.              │
# │       - Supports global efforts toward achieving the United Nations Sustainable Development Goals (SDGs).       │
# │                                                                                                                 │
# │     - **Sources:**                                                                                              │
# │       - Nature Journal Special Report on AI in Science (2024)                                                   │
# │       - World Economic Forum – AI for Sustainability Report (2024)                                              │
# │       - MIT Technology Review – AI-Powered Climate Solutions (2024)                                             │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  These three trends collectively highlight a shift toward AI that not only augments human creativity and        │
# │  decision-making but also addresses complex global challenges. The cross-cutting focus on ethical use,          │
# │  transparency, and sustainability signals maturity in AI development as these technologies move from            │
# │  experimental research to widespread practical deployments.                                                     │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: ef71f969-4261-4825-9167-9fc6d777d055                                                                     │
# │  Agent: Senior Research Analyst                                                                                 │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Technical Content Writer                                                                                │
# │                                                                                                                 │
# │  Task: Write a 500-word blog post based on the research findings. The post should be engaging and easy for a    │
# │  general audience to understand.                                                                                │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────────── Crew Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Completed                                                                                       │
# │  Name: crew                                                                                                     │
# │  ID: f2d128c8-7fa3-404e-9714-0a33cb35295a                                                                       │
# │  Tool Args:                                                                                                     │
# │  Final Output: **Top 3 Emerging AI Trends Shaping Our Future in 2024-2025**                                     │
# │                                                                                                                 │
# │  Artificial Intelligence continues to evolve at a breathtaking pace, reshaping our societies and industries in  │
# │  profound ways. As we look into 2024 and 2025, three key AI trends stand out—not only for their technological   │
# │  advancements but also for their practical applications and potential impact on our daily lives and the global  │
# │  community. Here’s an accessible dive into these transformative trends and what they mean for us all.           │
# │                                                                                                                 │
# │  **1. The Rise of Generative AI and Foundation Models**                                                         │
# │                                                                                                                 │
# │  Generative AI, powered by massive foundation models like GPT-4, Google’s PaLM 2, and cutting-edge multimodal   │
# │  systems, is revolutionizing how machines create content. Unlike earlier AI that was specialized in one         │
# │  domain, these “foundation” models are capable of producing a remarkable variety of outputs—text, images,       │
# │  audio, even video—all within a single integrated system. This multimodal ability means machines not only       │
# │  understand different forms of information but can also seamlessly blend them, enhancing creative and           │
# │  automated workflows.                                                                                           │
# │                                                                                                                 │
# │  What does this mean in real life? Businesses can now automate marketing materials tailored to individual       │
# │  customers, generate code snippets to ease software development, and build chatbots that hold genuinely         │
# │  human-like conversations. AI-as-a-service platforms have made this technology accessible across industries,    │
# │  empowering companies of all sizes to innovate without massive tech overheads. However, this power comes with   │
# │  the responsibility to use AI ethically—avoiding misinformation, bias, and misuse has become a paramount        │
# │  concern, prompting new regulations and standards.                                                              │
# │                                                                                                                 │
# │  Industries such as media, education, and customer service are already feeling this wave, where productivity    │
# │  and creative possibilities are boosted like never before. Imagine personalized learning tools adapting in      │
# │  real-time to your needs or media content generated instantly to match your interests. The transformative       │
# │  potential here is enormous, touching every corner of how we create and communicate.                            │
# │                                                                                                                 │
# │  **2. AI-Driven Automation Elevating Knowledge Work and Decision-Making**                                       │
# │                                                                                                                 │
# │  Beyond content creation, AI is increasingly partnering with humans to transform complex knowledge work. Tasks  │
# │  like reviewing legal documents, analyzing financial data, and diagnosing medical conditions are becoming       │
# │  faster and more accurate through AI automation. Importantly, these AI systems don’t just replace human         │
# │  efforts—they augment them by combining human judgment and AI insights for smarter decisions.                   │
# │                                                                                                                 │
# │  Explainable AI (XAI) has emerged as a critical component, especially in regulated fields like healthcare and   │
# │  finance, where stakeholders need transparency in how decisions are made. Robotic Process Automation (RPA)      │
# │  powered by AI now tackles unstructured data—emails, reports, images—automating workflows previously thought    │
# │  too complex.                                                                                                   │
# │                                                                                                                 │
# │  Real-time analytics and predictive insights enable companies to anticipate risks, optimize supply chains, and  │
# │  adapt swiftly to market changes. Rather than job losses, these technologies create hybrid roles where humans   │
# │  and AI collaborate, unleashing new productivity and innovation.                                                │
# │                                                                                                                 │
# │  This blending of human expertise with AI accelerates business efficiency and quality, helping organizations    │
# │  navigate complexity with confidence and agility.                                                               │
# │                                                                                                                 │
# │  **3. AI for Scientific Discovery and Environmental Sustainability**                                            │
# │                                                                                                                 │
# │  Perhaps most inspiring is AI’s role in addressing critical global challenges. In science, AI expedites         │
# │  discoveries in drug development, materials engineering, and genomics—fields traditionally slowed by trial and  │
# │  error—by predicting molecules and designing experiments with unprecedented speed. Climate science also         │
# │  benefits from AI’s ability to simulate complex models and monitor environmental changes in real-time,          │
# │  providing actionable data to combat climate change.                                                            │
# │                                                                                                                 │
# │  AI-driven autonomous robots are deployed in environmental cleanup, precision farming, and protecting           │
# │  biodiversity, supporting sustainability efforts on the ground. Furthermore, AI-human collaborative research    │
# │  platforms accelerate hypothesis testing and innovation, democratizing access to high-powered scientific        │
# │  tools.                                                                                                         │
# │                                                                                                                 │
# │  The emphasis on ethical innovation ensures that rapid progress does not come at the expense of environmental   │
# │  or social integrity. By aligning AI with the United Nations Sustainable Development Goals, these technologies  │
# │  support a healthier planet and society.                                                                        │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  **Looking Ahead**                                                                                              │
# │                                                                                                                 │
# │  Together, these three AI trends represent a maturing ecosystem where AI is not only smarter and more           │
# │  versatile but also more responsible and collaborative. Whether it’s unleashing creativity through generative   │
# │  models, enhancing decisions in knowledge-driven professions, or driving breakthroughs in science and           │
# │  sustainability, AI is firmly embedding itself as a powerful partner to humanity.                               │
# │                                                                                                                 │
# │  As these technologies become mainstream, the challenge lies in harnessing their full potential while ensuring  │
# │  ethical use, transparency, and inclusivity. The future of AI beckons a world where innovation and              │
# │  responsibility go hand in hand—opening doors to unprecedented opportunities that can impact all of us          │
# │  positively.                                                                                                    │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  *Sources: OpenAI GPT-4 Technical Report (2024), Google AI Blog on PaLM 2 (2024), Stanford Institute for        │
# │  Human-Centered AI Annual Report (2024), McKinsey Global AI Survey 2024, Gartner Hype Cycle 2024, Deloitte      │
# │  Insights 2024, Nature Journal AI in Science 2024, World Economic Forum AI for Sustainability 2024, MIT         │
# │  Technology Review 2024*                                                                                        │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: 48ed43c3-f04e-4385-be3e-f5d9721c1d87                                                                     │
# │  Agent: Technical Content Writer                                                                                │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────── Tracing Preference Saved ──────────────────────────╮
# │                                                                              │
# │  Info: Tracing has been disabled.                                            │
# │                                                                              │
# │  Your preference has been saved. Future Crew/Flow executions will not        │
# │  collect traces.                                                             │
# │                                                                              │
# │  To enable tracing later, do any one of these:                               │
# │  • Set tracing=True in your Crew/Flow code                                   │
# │  • Set CREWAI_TRACING_ENABLED=true in your project's .env file               │
# │  • Run: crewai traces enable                                                 │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
